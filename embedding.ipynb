# %%
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Users\Abhis\OneDrive\Desktop\Projects\Mini Projects\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
sent = [
    "The sun is shining brightly today.",
    "I need to buy groceries after work.",
    "She finished reading the book last night.",
    "The cat slept on the windowsill.",
    "Coffee is my favorite morning drink.",
]

# %%
sent
# Out:
# ['The sun is shining brightly today.',
#  'I need to buy groceries after work.',
#  'She finished reading the book last night.',
#  'The cat slept on the windowsill.',
#  'Coffee is my favorite morning drink.']

# %%
vocab_size = 10000

# %%
one_hot_rep = [one_hot(words,vocab_size) for words in sent]
one_hot_rep
# Out:
# [[8408, 2173, 7249, 1315, 7691, 2282],
#  [636, 3699, 2607, 8502, 9084, 2405, 9867],
#  [6826, 2018, 9242, 8408, 4578, 5967, 1112],
#  [8408, 61, 77, 3913, 8408, 4659],
#  [2878, 7249, 2319, 1210, 9895, 3192]]

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_rep, maxlen = sent_length, padding = 'pre')

# %%
print(embedded_docs)
# Out:
# [[   0    0 8408 2173 7249 1315 7691 2282]
#  [   0  636 3699 2607 8502 9084 2405 9867]
#  [   0 6826 2018 9242 8408 4578 5967 1112]
#  [   0    0 8408   61   77 3913 8408 4659]
#  [   0    0 2878 7249 2319 1210 9895 3192]]

# %%
dim = 10

# %%
model = Sequential()
model.add(Embedding(vocab_size, dim, input_length = sent_length))

model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\Users\Abhis\OneDrive\Desktop\Projects\Mini Projects\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Abhis\OneDrive\Desktop\Projects\Mini Projects\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 145ms/step
# array([[[ 0.03934741,  0.02563358, -0.03686788,  0.03056133,
#           0.02943149,  0.01513913,  0.04266248,  0.00769204,
#           0.01005377, -0.01157112],
#         [ 0.03934741,  0.02563358, -0.03686788,  0.03056133,
#           0.02943149,  0.01513913,  0.04266248,  0.00769204,
#           0.01005377, -0.01157112],
#         [-0.04251678, -0.00865209,  0.01628963, -0.02139655,
#           0.04237788, -0.00947024, -0.04388647, -0.03356697,
#           0.01591196,  0.02046794],
#         [-0.00109762, -0.04607103,  0.04225012,  0.04402738,
#           0.03315028, -0.02660509,  0.04066995,  0.02570749,
#           0.04799351, -0.01380565],
#         [-0.02587739, -0.01295479,  0.03850513,  0.03641405,
#           0.00312684, -0.00397398, -0.02806394,  0.0226743 ,
#          -0.0334563 , -0.04296471],
#         [ 0.01226284, -0.04359704, -0.0162065 ,  0.02525474,
#           0.00516566, -0.01694621,  0.02404156,  0.01196972,
#           0.03702488, -0.02393342],
#         [-0.03235118, -0.0228027 ,  0.02883985, -0.03181536,
#           0.00178272,  0.00687491,  0.03858611,  0.0223037 ,
#           0.00570814,  0.02255775],
#         [ 0.00302456,  0.01572101, -0.04260284,  0.00744224,
#          -0.02276289,  0.02592189,  0.00796062, -0.03972943,
#           0.03746214,  0.03074289]],
#
#        [[ 0.03934741,  0.02563358, -0.03686788,  0.03056133,
#           0.02943149,  0.01513913,  0.04266248,  0.00769204,
#           0.01005377, -0.01157112],
#         [-0.00968196, -0.00744398, -0.00918547, -0.01226532,
#           0.04884252,  0.03767749,  0.01558229,  0.00988556,
#          -0.02786922, -0.04977376],
#         [-0.01688213,  0.04702082,  0.02498115, -0.03931866,
#           0.04781245, -0.04139926, -0.01961309, -0.03643455,
#           0.04056093,  0.03941865],
#         [-0.02353486,  0.01415053, -0.00494117,  0.02845938,
#          -0.00606476,  0.02438089,  0.01731754, -0.01347731,
#           0.04731499,  0.01372843],
#         [ 0.00054731,  0.02202481,  0.04922601, -0.0095259 ,
#          -0.04461067, -0.04487214,  0.0189165 , -0.0130037 ,
#           0.00620824,  0.01747379],
#         [-0.04674796,  0.03268803,  0.02129556, -0.0272262 ,
#           0.044907  ,  0.03202845, -0.00581224, -0.03079191,
#           0.0494763 , -0.03293803],
#         [ 0.00198786,  0.0255334 , -0.00155556, -0.04161669,
#          -0.03007623,  0.00921177, -0.02361943, -0.02585429,
#          -0.04905156,  0.03110819],
#         [ 0.00890804,  0.0305802 , -0.02201428, -0.0341896 ,
#           0.03571865, -0.00571632, -0.04578841, -0.0423347 ,
#          -0.02594715,  0.01686339]],
#
#        [[ 0.03934741,  0.02563358, -0.03686788,  0.03056133,
#           0.02943149,  0.01513913,  0.04266248,  0.00769204,
#           0.01005377, -0.01157112],
#         [ 0.00068786, -0.03156056, -0.03512094, -0.01426984,
#           0.02527423, -0.00423146,  0.00034965,  0.01962802,
#           0.03128258, -0.03498541],
#         [ 0.04959253,  0.01990546,  0.03180057, -0.00185223,
#          -0.00915744,  0.01257289,  0.01385165,  0.03583999,
#          -0.04516418,  0.00034928],
#         [-0.03794117, -0.04850358, -0.00560552, -0.01259281,
#          -0.04807327, -0.02259639, -0.00125976, -0.01192909,
#          -0.04596531,  0.00881169],
#         [-0.04251678, -0.00865209,  0.01628963, -0.02139655,
#           0.04237788, -0.00947024, -0.04388647, -0.03356697,
#           0.01591196,  0.02046794],
#         [ 0.02571094, -0.03984712, -0.01859007,  0.03736291,
#           0.0060874 ,  0.02797357, -0.01880484, -0.00205487,
#          -0.03671472, -0.01895602],
#         [-0.04444769,  0.01710166,  0.00986411, -0.02968874,
#          -0.00620826,  0.02362243, -0.00023516,  0.04746998,
#           0.0237344 , -0.01567994],
#         [ 0.0095772 , -0.02196124,  0.01330512, -0.02794145,
#           0.0050318 ,  0.03381688,  0.01526118, -0.04134987,
#          -0.02350105,  0.03583517]],
#
#        [[ 0.03934741,  0.02563358, -0.03686788,  0.03056133,
#           0.02943149,  0.01513913,  0.04266248,  0.00769204,
#           0.01005377, -0.01157112],
#         [ 0.03934741,  0.02563358, -0.03686788,  0.03056133,
#           0.02943149,  0.01513913,  0.04266248,  0.00769204,
#           0.01005377, -0.01157112],
#         [-0.04251678, -0.00865209,  0.01628963, -0.02139655,
#           0.04237788, -0.00947024, -0.04388647, -0.03356697,
#           0.01591196,  0.02046794],
#         [-0.00332265,  0.04569366, -0.00367843, -0.03892574,
#          -0.01733977, -0.02645468,  0.01633183,  0.00961129,
#          -0.04300624, -0.04576286],
#         [-0.00083601, -0.04361088,  0.01087283,  0.00205899,
#          -0.00873404, -0.04753409,  0.03340962,  0.02884276,
#          -0.00375533, -0.02841712],
#         [ 0.03814259, -0.01642941, -0.04868995, -0.0013193 ,
#          -0.02718649,  0.03481739, -0.03150283,  0.02310998,
#           0.00023639,  0.02264011],
#         [-0.04251678, -0.00865209,  0.01628963, -0.02139655,
#           0.04237788, -0.00947024, -0.04388647, -0.03356697,
#           0.01591196,  0.02046794],
#         [ 0.0227879 ,  0.04770991,  0.03004166, -0.00708705,
#           0.02055204,  0.00907379,  0.00670574, -0.00715571,
#           0.02317699, -0.04016823]],
#
#        [[ 0.03934741,  0.02563358, -0.03686788,  0.03056133,
#           0.02943149,  0.01513913,  0.04266248,  0.00769204,
#           0.01005377, -0.01157112],
#         [ 0.03934741,  0.02563358, -0.03686788,  0.03056133,
#           0.02943149,  0.01513913,  0.04266248,  0.00769204,
#           0.01005377, -0.01157112],
#         [ 0.04933492,  0.03698281,  0.03858644, -0.04723286,
#          -0.01651263, -0.02671856, -0.00653259, -0.04501694,
#          -0.01418508, -0.04661423],
#         [-0.02587739, -0.01295479,  0.03850513,  0.03641405,
#           0.00312684, -0.00397398, -0.02806394,  0.0226743 ,
#          -0.0334563 , -0.04296471],
#         [ 0.0387272 ,  0.00697647,  0.01335231,  0.00016659,
#           0.03436328, -0.02456626,  0.0487618 , -0.02454184,
#          -0.01197733, -0.00176265],
#         [ 0.02201534,  0.03601093,  0.01198582, -0.03467673,
#           0.03407473,  0.01949329,  0.03490378, -0.03883868,
#           0.03091638, -0.00209211],
#         [ 0.0220366 , -0.03550261, -0.04747352,  0.03302487,
#           0.00578586, -0.02180557,  0.01606845, -0.01856925,
#          -0.01325058, -0.01639154],
#         [-0.02477228,  0.03785583, -0.01461036, -0.02571819,
#           0.03740693, -0.01733925,  0.00962957,  0.00377911,
#           0.01218379,  0.03153547]]], dtype=float32)
